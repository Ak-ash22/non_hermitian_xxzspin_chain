# %%
# %run my_functions_generalized.ipynb

# %%
D1 = [-1]*10
D2 = [-0.5]*10
D3 = [0]*10
D4 = [0.5]*10
D5 = [1]*10
D6 = [2]*10
#D7 = [10]*10

# %% [markdown]
# ## n = 3

# %%
hz1 = np.linspace(0,0,10).tolist()
hz2 = np.linspace(-1,1,10).tolist()
hz3 = np.linspace(-0.1,0.1,10).tolist()
hz4 = np.linspace(-0.1,0.1,10).tolist()
hz5 = np.linspace(-1,1,10).tolist()
hz6 = np.linspace(-0,0,10).tolist()
#hz7 = np.linspace(0,0,10).tolist()

# %% [markdown]
# ## n = 4

# %%
hz1_4 = np.linspace(-1,1,10).tolist()
hz2_4 = np.linspace(-0.05,0.05,10).tolist()
hz3_4 = np.linspace(-0.5,0.5,10).tolist()
hz4_4 = np.linspace(-0.05,0.05,10).tolist()
hz5_4 = np.linspace(-1,1,10).tolist()
hz6_4 = np.linspace(-0,0,10).tolist()

# %% [markdown]
# ## n = 5

# %%
hz1_5 = np.linspace(-0,0,10)
hz2_5 = np.linspace(-0.05,0.05,10)
hz3_5 = np.linspace(-0.03,0.03,10)
hz4_5 = np.linspace(-0.05,0.05,10)
hz5_5 = np.linspace(-1,1,10)
hz6_5 = np.linspace(-0,0,10)

# %% [markdown]
# ## n = 6

# %%
hz1_6 = np.linspace(-1,1,10)
hz2_6 = np.linspace(-0.01,0.01,10)
hz3_6 = np.linspace(0,0,10)
hz4_6 = np.linspace(-0.01,0.01,10)
hz5_6 = np.linspace(-1,1,10)
hz6_6 = np.linspace(-0,0,10)

# %% [markdown]
# ## n = 7

# %%
hz1_7 = np.linspace(0,0,10)
hz2_7 = np.linspace(-0.2,0.2,10)
hz3_7 = np.linspace(-0.019,0.019,10)
hz4_7 = np.linspace(0,0,10)
hz5_7 = np.linspace(-1,1,10)
hz6_7 = np.linspace(-0,0,10)

# %%
plt.figure(figsize=(10,10))
plt.subplot(5,1,1)
plt.plot(hz1,D1,label='D=-1')
plt.plot(hz2,D2,label='D=-0.5')
plt.plot(hz3,D3,label='D=0')
plt.plot(hz4,D4,label='D=0.5')
plt.plot(hz5,D5,label='D=1')
plt.plot(hz6,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz')
plt.title('(n,hx) = {}'.format((3,1)))
plt.ylim(-2,2)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,2)
plt.plot(hz1_4,D1,label='D=-1')
plt.plot(hz2_4,D2,label='D=-0.5')
plt.plot(hz3_4,D3,label='D=0')
plt.plot(hz4_4,D4,label='D=0.5')
plt.plot(hz5_4,D5,label='D=1')
plt.plot(hz6_4,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz')
plt.title('(n,hx) = {}'.format((4,1)))
plt.ylim(-2,2)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,3)
plt.plot(hz1_5,D1,label='D=-1')
plt.plot(hz2_5,D2,label='D=-0.5')
plt.plot(hz3_5,D3,label='D=0')
plt.plot(hz4_5,D4,label='D=0.5')
plt.plot(hz5_5,D5,label='D=1')
plt.plot(hz6_5,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz')
plt.title('(n,hx) = {}'.format((5,1)))
plt.ylim(-2,2)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,4)
plt.plot(hz1_6,D1,label='D=-1')
plt.plot(hz2_6,D2,label='D=-0.5')
plt.plot(hz3_6,D3,label='D=0')
plt.plot(hz4_6,D4,label='D=0.5')
plt.plot(hz5_6,D5,label='D=1')
plt.plot(hz6_6,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz')
plt.title('(n,hx) = {}'.format((6,1)))
plt.ylim(-2,2)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,5)
plt.plot(hz1_7,D1,label='D=-1')
plt.plot(hz2_7,D2,label='D=-0.5')
plt.plot(hz3_7,D3,label='D=0')
plt.plot(hz4_7,D4,label='D=0.5')
plt.plot(hz5_7,D5,label='D=1')
plt.plot(hz6_7,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz')
plt.title('(n,hx) = {}'.format((7,1)))
plt.ylim(-2,2)
plt.xlim(-2,2)

plt.legend()
plt.show()

# %% [markdown]
# ## Varying hx for n = 3

# %%
D1 = [-1]*10
D2 = [-0.5]*10
D3 = [0]*10
D4 = [0.5]*10
D5 = [1]*10
D6 = [2]*10

# %%
# For hx = 1
Hz_1 = np.linspace(0,0,10)
Hz_2 = np.linspace(-1,1,10)
Hz_3 = np.linspace(-0.1,0.1,10)
Hz_4 = np.linspace(-0.1,0.1,10)
Hz_5 = np.linspace(-1,1,10)
Hz_6 = np.linspace(-0,0,10)

# %%
# For hx = 2
Hz1_1 = np.linspace(-0.02,0.02,10)
Hz2_1 = np.linspace(-1,1,10)
Hz3_1 = np.linspace(-0.3,0.3,10)
Hz4_1 = np.linspace(-0.3,0.3,10)
Hz5_1 = np.linspace(-1,1,10)
Hz6_1 = np.linspace(-0,0,10)

# %%
# For hx = 4
Hz1_2 = np.linspace(-0.1,0.1,10)
Hz2_2 = np.linspace(-0.8,0.8,10)
Hz3_2 = np.linspace(-0.5,0.5,10)
Hz4_2 = np.linspace(-0.6,0.6,10)
Hz5_2 = np.linspace(-1,1,10)
Hz6_2 = np.linspace(-0.05,0.05,10)

# %%
# For hx = 10
Hz1_3 = np.linspace(-0.2,0.2,10)
Hz2_3 = np.linspace(-0.85,0.85,10)
Hz3_3 = np.linspace(-0.8,0.8,10)
Hz4_3 = np.linspace(-0.8,0.8,10)
Hz5_3 = np.linspace(-1,1,10)
Hz6_3 = np.linspace(-0.1,0.1,10)

# %%
# For hx = 50
Hz1_4 = np.linspace(-0.2,0.2,10)
Hz2_4 = np.linspace(-1,1,10)
Hz3_4 = np.linspace(-1,1,10)
Hz4_4 = np.linspace(-1,1,10)
Hz5_4 = np.linspace(-1,1,10)
Hz6_4 = np.linspace(-0.15,0.15,10)

# %%
plt.figure(figsize=(10,10))
plt.subplot(5,1,1)
plt.plot(Hz_1,D1,label='D=-1')
plt.plot(Hz_2,D2,label='D=-0.5')
plt.plot(Hz_3,D3,label='D=0')
plt.plot(Hz_4,D4,label='D=0.5')
plt.plot(Hz_5,D5,label='D=1')
plt.plot(Hz_6,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz')
plt.title('(n,hx) = {}'.format((3,1)))
plt.ylim(-3,3)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,2)
plt.plot(Hz1_1,D1,label='D=-1')
plt.plot(Hz2_1,D2,label='D=-0.5')
plt.plot(Hz3_1,D3,label='D=0')
plt.plot(Hz4_1,D4,label='D=0.5')
plt.plot(Hz5_1,D5,label='D=1')
plt.plot(Hz6_1,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz/hx')
plt.title('(n,hx) = {}'.format((3,2)))
plt.ylim(-3,3)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,3)
plt.plot(Hz1_2,D1,label='D=-1')
plt.plot(Hz2_2,D2,label='D=-0.5')
plt.plot(Hz3_2,D3,label='D=0')
plt.plot(Hz4_2,D4,label='D=0.5')
plt.plot(Hz5_2,D5,label='D=1')
plt.plot(Hz6_2,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz/hx')
plt.title('(n,hx) = {}'.format((3,4)))
plt.ylim(-3,3)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,4)
plt.plot(Hz1_3,D1,label='D=-1')
plt.plot(Hz2_3,D2,label='D=-0.5')
plt.plot(Hz3_3,D3,label='D=0')
plt.plot(Hz4_3,D4,label='D=0.5')
plt.plot(Hz5_3,D5,label='D=1')
plt.plot(Hz6_3,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz/hx')
plt.title('(n,hx) = {}'.format((3,10)))
plt.ylim(-3,3)
plt.xlim(-2,2)
plt.legend()

plt.figure(figsize=(10,10))
plt.subplot(5,1,4)
plt.plot(Hz1_4,D1,label='D=-1')
plt.plot(Hz2_4,D2,label='D=-0.5')
plt.plot(Hz3_4,D3,label='D=0')
plt.plot(Hz4_4,D4,label='D=0.5')
plt.plot(Hz5_4,D5,label='D=1')
plt.plot(Hz6_4,D6,label='D=2')
#plt.plot(hz7,D7)
plt.ylabel('D')
plt.xlabel('hz/hx')
plt.title('(n,hx) = {}'.format((3,50)))
plt.ylim(-3,3)
plt.xlim(-2,2)
plt.legend()

plt.show()
