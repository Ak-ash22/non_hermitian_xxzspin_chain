# %%
# %run my_functions_generalized.ipynb

# %%
hx1 = [1]*100
hz1 = np.linspace(-1*hx1[0],1*hx1[0],100,endpoint = False)
d1 = [1]*100

hzhx1 = []
for i in range(len(hz1)):
    hzhx1.append(hz1[i]/hx1[i])

# %%
hx = [1]
hz = [-0.99]
d = [1]
H1 = Hamiltonian(4,2,hx,hz,d) 
S_c = biorthogonal_entropy(H1,1,2)
S_c
# Out:
# array([0.99876-0.j])

# %%
H = Hamiltonian(4,2,hx1,hz1,d1)
np.round(np.linalg.eigvals(H[0]).imag,6)
# Out:
# array([-0.000e+00,  1.200e-05, -7.000e-06, -4.000e-06,  5.210e-04,
#        -9.450e-04,  1.267e-03,  2.630e-04, -1.105e-03,  0.000e+00,
#         0.000e+00,  0.000e+00, -0.000e+00, -0.000e+00, -0.000e+00,
#        -0.000e+00])

# %%
S_c = biorthogonal_entropy(H,1,2)
S_c
# Out:
# array([1.     -0.j, 0.99754-0.j, 0.99515-0.j, 0.99284-0.j, 0.9906 +0.j,
#        0.98844-0.j, 0.98634-0.j, 0.98432+0.j, 0.98236+0.j, 0.98046-0.j,
#        0.97863+0.j, 0.97686+0.j, 0.97515+0.j, 0.9735 -0.j, 0.9719 -0.j,
#        0.97037-0.j, 0.96888-0.j, 0.96745+0.j, 0.96608+0.j, 0.96475+0.j,
#        0.96348-0.j, 0.96225+0.j, 0.96108+0.j, 0.95995+0.j, 0.95887-0.j,
#        0.95784-0.j, 0.95685+0.j, 0.95591+0.j, 0.95501+0.j, 0.95416+0.j,
#        0.95335-0.j, 0.95258-0.j, 0.95185+0.j, 0.95117-0.j, 0.95053-0.j,
#        0.94993-0.j, 0.94937-0.j, 0.94885+0.j, 0.94837-0.j, 0.94792+0.j,
#        0.94752-0.j, 0.94716+0.j, 0.94684-0.j, 0.94655-0.j, 0.9463 -0.j,
#        0.9461 -0.j, 0.94592+0.j, 0.94579-0.j, 0.9457 +0.j, 0.94564-0.j,
#        0.94562+0.j, 0.94564-0.j, 0.9457 +0.j, 0.94579+0.j, 0.94592+0.j,
#        0.9461 -0.j, 0.9463 -0.j, 0.94655-0.j, 0.94684-0.j, 0.94716-0.j,
#        0.94752+0.j, 0.94792+0.j, 0.94837-0.j, 0.94885-0.j, 0.94937-0.j,
# ...

# %%
plt.plot(hzhx1,S_c,color='r')
plt.show()
# Out:
# /home/akash/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
