# %%
# %run my_functions_generalized.ipynb
import scipy

# %%
# Intially    at t=0 let psi be |110>
# ket_0 = np.array([0,1]).reshape(2,1)
# ket_1 = np.array([1,0]).reshape(2,1)
# psi_t0 = np.kron(ket_1,np.kron(ket_1,ket_0)).reshape(8,1)

# %%
hx = [1]*5
hz = [-0.99,-0.5,0,0.5,0.99]
d = [1]*5

# %% [markdown]
# ## n = 3

# %%
#S_gs = [0.5]*1000
#time = np.linspace(0,1000,1000)
plot_entropy_t(3,2,1,1,hx,hz,d)
#plt.plot(time,S_gs,color='b')
#plt.show()

# %% [markdown]
# ## n = 4

# %%
plot_entropy_t(4,2,1,2,hx,hz,d)

# %% [markdown]
# ## n = 5

# %%
plot_entropy_t(5,3,2,2,hx,hz,d)

# %% [markdown]
# ## n = 6

# %%
plot_entropy_t(6,3,2,3,hx,hz,d)

# %% [markdown]
# ## n = 7

# %%
plot_entropy_t(7,4,3,3,hx,hz,d)

# %% [markdown]
# ## n = 8

# %%
#plot_entropy_t(8,4,3,4,hx,hz,d)

# %% [markdown]
# ## n = 9

# %%
#plot_entropy_t(9,5,4,4,hx,hz,d)

# %% [markdown]
# ## n spins for hz = -0.9

# %%
for i in range(6):
    plt.subplot(6,i+1,1)
    plt.figure(figsize=(6,3))
    if (i%2) == 0:
        plot_entropy_t(i+3,(i+4)/2,int((i+2)/2),int((i+2)/2),hx=[1],hz=[-0.99],d=[1])
    else:
        plot_entropy_t(i+3,(i+3)/2,int(((i+3)/2)-1),int((i+3)/2),hx=[1],hz=[-0.99],d=[1])
